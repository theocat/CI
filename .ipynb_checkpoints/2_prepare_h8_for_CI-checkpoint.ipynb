# %%
import numpy as np
import bz2file
import struct
import os,time
from read_hrit import read_hrit

# %%
time_s=time.mktime(time.strptime('201806270300','%Y%m%d%H%M'))
time_e=time.mktime(time.strptime('201806271000','%Y%m%d%H%M'))
times_out=np.arange(time_s,time_e+1,10*60)

# %%
path_in_0 = '/work/share/HRIT_brands/'
path_in_1 = '/data/Back_up/HRIT_brands/'

# %%
path_out_0 = '/work/wuxue/data/CI/h8_for_CI/'

# %%
brands=['B04','B05','B06','B07','B09','B10','B11','B12', 'B14','B16','IR1','IR2','IR3','IR4','VIS']

# %%
areas = ['001','002','003','004','005','006','007','008','009','010']

# %%
for time_out in times_out:
    time_c = time.strftime("%Y%m%d%H%M", time.localtime(time_out))
    print('========= '+ time_c +' ===================')
    for brand in brands:
        print brand

        if os.path.exists(path_in_0 + brand+'/'+ time_c[0:8]+'/'):
            path_in = path_in_0 + brand+'/'+ time_c[0:8]+'/'
        elif os.path.exists(path_in_1 + brand+'/'+ time_c[0:8]+'/'):
            path_in = path_in_1 + brand+'/'+ time_c[0:8]+'/'
        else:
            print('No Data of '+ brand)
            continue
        file_in = 'IMG_DK01'+ brand +'_'+ time_c

        path_out = path_out_0 + time_c[0:8]+'/'+ time_c+'/'
        if os.path.exists(path_out)==False:
            os.makedirs(path_out)    
        file_out = 'H8_HRIT_FLDK_'+brand+'_'+time_c+'.dat'   

        try:
            TB1 = read_hrit(path_in + file_in +'_001.bz2')
            TB2 = read_hrit(path_in + file_in +'_002.bz2')
            TB3 = read_hrit(path_in + file_in +'_003.bz2')
            TB4 = read_hrit(path_in + file_in +'_004.bz2')
            TB5 = np.zeros_like(TB1)
            TB6 = np.zeros_like(TB1)
            TB7 = np.zeros_like(TB1)
            TB8 = np.zeros_like(TB1)
            TB9 = np.zeros_like(TB1)
            TB10 = np.zeros_like(TB1)
        except:
            print('Data missing.')
            continue

        TB = np.row_stack((TB1,TB2,TB3,TB4,TB5,TB6,TB7,TB8,TB9,TB10))
        TB = TB*10
        TB = np.array(TB,'short')
    
        f=open(path_out+file_out,'wb')
        f.write(TB)
        f.close()
        print(file_out)
# Out:
# ========= 201806140300 ===================
# B04
# H8_HRIT_FLDK_B04_201806140300.dat
# B05
# H8_HRIT_FLDK_B05_201806140300.dat
# B06
# H8_HRIT_FLDK_B06_201806140300.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140300.dat
# B10
# H8_HRIT_FLDK_B10_201806140300.dat
# B11
# H8_HRIT_FLDK_B11_201806140300.dat
# B12
# H8_HRIT_FLDK_B12_201806140300.dat
# B14
# H8_HRIT_FLDK_B14_201806140300.dat
# B16
# H8_HRIT_FLDK_B16_201806140300.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140300.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140300.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140300.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140300.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140300.dat
# ========= 201806140310 ===================
# B04
# H8_HRIT_FLDK_B04_201806140310.dat
# B05
# H8_HRIT_FLDK_B05_201806140310.dat
# B06
# H8_HRIT_FLDK_B06_201806140310.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140310.dat
# B10
# H8_HRIT_FLDK_B10_201806140310.dat
# B11
# H8_HRIT_FLDK_B11_201806140310.dat
# B12
# H8_HRIT_FLDK_B12_201806140310.dat
# B14
# H8_HRIT_FLDK_B14_201806140310.dat
# B16
# H8_HRIT_FLDK_B16_201806140310.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140310.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140310.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140310.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140310.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140310.dat
# ========= 201806140320 ===================
# B04
# H8_HRIT_FLDK_B04_201806140320.dat
# B05
# H8_HRIT_FLDK_B05_201806140320.dat
# B06
# H8_HRIT_FLDK_B06_201806140320.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140320.dat
# B10
# H8_HRIT_FLDK_B10_201806140320.dat
# B11
# H8_HRIT_FLDK_B11_201806140320.dat
# B12
# H8_HRIT_FLDK_B12_201806140320.dat
# B14
# H8_HRIT_FLDK_B14_201806140320.dat
# B16
# H8_HRIT_FLDK_B16_201806140320.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140320.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140320.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140320.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140320.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140320.dat
# ========= 201806140330 ===================
# B04
# H8_HRIT_FLDK_B04_201806140330.dat
# B05
# H8_HRIT_FLDK_B05_201806140330.dat
# B06
# H8_HRIT_FLDK_B06_201806140330.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140330.dat
# B10
# H8_HRIT_FLDK_B10_201806140330.dat
# B11
# H8_HRIT_FLDK_B11_201806140330.dat
# B12
# H8_HRIT_FLDK_B12_201806140330.dat
# B14
# H8_HRIT_FLDK_B14_201806140330.dat
# B16
# H8_HRIT_FLDK_B16_201806140330.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140330.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140330.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140330.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140330.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140330.dat
# ========= 201806140340 ===================
# B04
# H8_HRIT_FLDK_B04_201806140340.dat
# B05
# H8_HRIT_FLDK_B05_201806140340.dat
# B06
# H8_HRIT_FLDK_B06_201806140340.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140340.dat
# B10
# H8_HRIT_FLDK_B10_201806140340.dat
# B11
# H8_HRIT_FLDK_B11_201806140340.dat
# B12
# H8_HRIT_FLDK_B12_201806140340.dat
# B14
# H8_HRIT_FLDK_B14_201806140340.dat
# B16
# H8_HRIT_FLDK_B16_201806140340.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140340.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140340.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140340.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140340.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140340.dat
# ========= 201806140350 ===================
# B04
# H8_HRIT_FLDK_B04_201806140350.dat
# B05
# H8_HRIT_FLDK_B05_201806140350.dat
# B06
# H8_HRIT_FLDK_B06_201806140350.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140350.dat
# B10
# H8_HRIT_FLDK_B10_201806140350.dat
# B11
# H8_HRIT_FLDK_B11_201806140350.dat
# B12
# H8_HRIT_FLDK_B12_201806140350.dat
# B14
# H8_HRIT_FLDK_B14_201806140350.dat
# B16
# H8_HRIT_FLDK_B16_201806140350.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140350.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140350.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140350.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140350.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140350.dat
# ========= 201806140400 ===================
# B04
# H8_HRIT_FLDK_B04_201806140400.dat
# B05
# H8_HRIT_FLDK_B05_201806140400.dat
# B06
# H8_HRIT_FLDK_B06_201806140400.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140400.dat
# B10
# H8_HRIT_FLDK_B10_201806140400.dat
# B11
# H8_HRIT_FLDK_B11_201806140400.dat
# B12
# H8_HRIT_FLDK_B12_201806140400.dat
# B14
# H8_HRIT_FLDK_B14_201806140400.dat
# B16
# H8_HRIT_FLDK_B16_201806140400.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140400.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140400.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140400.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140400.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140400.dat
# ========= 201806140410 ===================
# B04
# H8_HRIT_FLDK_B04_201806140410.dat
# B05
# H8_HRIT_FLDK_B05_201806140410.dat
# B06
# H8_HRIT_FLDK_B06_201806140410.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140410.dat
# B10
# H8_HRIT_FLDK_B10_201806140410.dat
# B11
# H8_HRIT_FLDK_B11_201806140410.dat
# B12
# H8_HRIT_FLDK_B12_201806140410.dat
# B14
# H8_HRIT_FLDK_B14_201806140410.dat
# B16
# H8_HRIT_FLDK_B16_201806140410.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140410.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140410.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140410.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140410.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140410.dat
# ========= 201806140420 ===================
# B04
# H8_HRIT_FLDK_B04_201806140420.dat
# B05
# H8_HRIT_FLDK_B05_201806140420.dat
# B06
# H8_HRIT_FLDK_B06_201806140420.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140420.dat
# B10
# H8_HRIT_FLDK_B10_201806140420.dat
# B11
# H8_HRIT_FLDK_B11_201806140420.dat
# B12
# H8_HRIT_FLDK_B12_201806140420.dat
# B14
# H8_HRIT_FLDK_B14_201806140420.dat
# B16
# H8_HRIT_FLDK_B16_201806140420.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140420.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140420.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140420.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140420.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140420.dat
# ========= 201806140430 ===================
# B04
# H8_HRIT_FLDK_B04_201806140430.dat
# B05
# H8_HRIT_FLDK_B05_201806140430.dat
# B06
# H8_HRIT_FLDK_B06_201806140430.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140430.dat
# B10
# H8_HRIT_FLDK_B10_201806140430.dat
# B11
# H8_HRIT_FLDK_B11_201806140430.dat
# B12
# H8_HRIT_FLDK_B12_201806140430.dat
# B14
# H8_HRIT_FLDK_B14_201806140430.dat
# B16
# H8_HRIT_FLDK_B16_201806140430.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140430.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140430.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140430.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140430.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140430.dat
# ========= 201806140440 ===================
# B04
# H8_HRIT_FLDK_B04_201806140440.dat
# B05
# H8_HRIT_FLDK_B05_201806140440.dat
# B06
# H8_HRIT_FLDK_B06_201806140440.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140440.dat
# B10
# H8_HRIT_FLDK_B10_201806140440.dat
# B11
# H8_HRIT_FLDK_B11_201806140440.dat
# B12
# H8_HRIT_FLDK_B12_201806140440.dat
# B14
# Data missing.
# B16
# H8_HRIT_FLDK_B16_201806140440.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140440.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140440.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140440.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140440.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140440.dat
# ========= 201806140450 ===================
# B04
# H8_HRIT_FLDK_B04_201806140450.dat
# B05
# H8_HRIT_FLDK_B05_201806140450.dat
# B06
# H8_HRIT_FLDK_B06_201806140450.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140450.dat
# B10
# H8_HRIT_FLDK_B10_201806140450.dat
# B11
# H8_HRIT_FLDK_B11_201806140450.dat
# B12
# H8_HRIT_FLDK_B12_201806140450.dat
# B14
# H8_HRIT_FLDK_B14_201806140450.dat
# B16
# H8_HRIT_FLDK_B16_201806140450.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140450.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140450.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140450.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140450.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140450.dat
# ========= 201806140500 ===================
# B04
# H8_HRIT_FLDK_B04_201806140500.dat
# B05
# H8_HRIT_FLDK_B05_201806140500.dat
# B06
# H8_HRIT_FLDK_B06_201806140500.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140500.dat
# B10
# H8_HRIT_FLDK_B10_201806140500.dat
# B11
# H8_HRIT_FLDK_B11_201806140500.dat
# B12
# H8_HRIT_FLDK_B12_201806140500.dat
# B14
# H8_HRIT_FLDK_B14_201806140500.dat
# B16
# H8_HRIT_FLDK_B16_201806140500.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140500.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140500.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140500.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140500.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140500.dat
# ========= 201806140510 ===================
# B04
# H8_HRIT_FLDK_B04_201806140510.dat
# B05
# H8_HRIT_FLDK_B05_201806140510.dat
# B06
# H8_HRIT_FLDK_B06_201806140510.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140510.dat
# B10
# H8_HRIT_FLDK_B10_201806140510.dat
# B11
# H8_HRIT_FLDK_B11_201806140510.dat
# B12
# H8_HRIT_FLDK_B12_201806140510.dat
# B14
# H8_HRIT_FLDK_B14_201806140510.dat
# B16
# H8_HRIT_FLDK_B16_201806140510.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140510.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140510.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140510.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140510.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140510.dat
# ========= 201806140520 ===================
# B04
# H8_HRIT_FLDK_B04_201806140520.dat
# B05
# Data missing.
# B06
# H8_HRIT_FLDK_B06_201806140520.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140520.dat
# B10
# H8_HRIT_FLDK_B10_201806140520.dat
# B11
# H8_HRIT_FLDK_B11_201806140520.dat
# B12
# H8_HRIT_FLDK_B12_201806140520.dat
# B14
# Data missing.
# B16
# Data missing.
# IR1
# Data missing.
# IR2
# H8_HRIT_FLDK_IR2_201806140520.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140520.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140520.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140520.dat
# ========= 201806140530 ===================
# B04
# H8_HRIT_FLDK_B04_201806140530.dat
# B05
# H8_HRIT_FLDK_B05_201806140530.dat
# B06
# H8_HRIT_FLDK_B06_201806140530.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140530.dat
# B10
# H8_HRIT_FLDK_B10_201806140530.dat
# B11
# H8_HRIT_FLDK_B11_201806140530.dat
# B12
# H8_HRIT_FLDK_B12_201806140530.dat
# B14
# H8_HRIT_FLDK_B14_201806140530.dat
# B16
# H8_HRIT_FLDK_B16_201806140530.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140530.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140530.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140530.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140530.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140530.dat
# ========= 201806140540 ===================
# B04
# H8_HRIT_FLDK_B04_201806140540.dat
# B05
# H8_HRIT_FLDK_B05_201806140540.dat
# B06
# H8_HRIT_FLDK_B06_201806140540.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140540.dat
# B10
# H8_HRIT_FLDK_B10_201806140540.dat
# B11
# H8_HRIT_FLDK_B11_201806140540.dat
# B12
# H8_HRIT_FLDK_B12_201806140540.dat
# B14
# H8_HRIT_FLDK_B14_201806140540.dat
# B16
# H8_HRIT_FLDK_B16_201806140540.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140540.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140540.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140540.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140540.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140540.dat
# ========= 201806140550 ===================
# B04
# H8_HRIT_FLDK_B04_201806140550.dat
# B05
# H8_HRIT_FLDK_B05_201806140550.dat
# B06
# H8_HRIT_FLDK_B06_201806140550.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140550.dat
# B10
# H8_HRIT_FLDK_B10_201806140550.dat
# B11
# H8_HRIT_FLDK_B11_201806140550.dat
# B12
# H8_HRIT_FLDK_B12_201806140550.dat
# B14
# H8_HRIT_FLDK_B14_201806140550.dat
# B16
# H8_HRIT_FLDK_B16_201806140550.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140550.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140550.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140550.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140550.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140550.dat
# ========= 201806140600 ===================
# B04
# H8_HRIT_FLDK_B04_201806140600.dat
# B05
# H8_HRIT_FLDK_B05_201806140600.dat
# B06
# H8_HRIT_FLDK_B06_201806140600.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140600.dat
# B10
# H8_HRIT_FLDK_B10_201806140600.dat
# B11
# H8_HRIT_FLDK_B11_201806140600.dat
# B12
# H8_HRIT_FLDK_B12_201806140600.dat
# B14
# H8_HRIT_FLDK_B14_201806140600.dat
# B16
# H8_HRIT_FLDK_B16_201806140600.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140600.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140600.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140600.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140600.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140600.dat
# ========= 201806140610 ===================
# B04
# H8_HRIT_FLDK_B04_201806140610.dat
# B05
# H8_HRIT_FLDK_B05_201806140610.dat
# B06
# H8_HRIT_FLDK_B06_201806140610.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140610.dat
# B10
# H8_HRIT_FLDK_B10_201806140610.dat
# B11
# H8_HRIT_FLDK_B11_201806140610.dat
# B12
# H8_HRIT_FLDK_B12_201806140610.dat
# B14
# H8_HRIT_FLDK_B14_201806140610.dat
# B16
# H8_HRIT_FLDK_B16_201806140610.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140610.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140610.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140610.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140610.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140610.dat
# ========= 201806140620 ===================
# B04
# H8_HRIT_FLDK_B04_201806140620.dat
# B05
# H8_HRIT_FLDK_B05_201806140620.dat
# B06
# H8_HRIT_FLDK_B06_201806140620.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140620.dat
# B10
# H8_HRIT_FLDK_B10_201806140620.dat
# B11
# H8_HRIT_FLDK_B11_201806140620.dat
# B12
# H8_HRIT_FLDK_B12_201806140620.dat
# B14
# H8_HRIT_FLDK_B14_201806140620.dat
# B16
# H8_HRIT_FLDK_B16_201806140620.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140620.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140620.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140620.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140620.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140620.dat
# ========= 201806140630 ===================
# B04
# H8_HRIT_FLDK_B04_201806140630.dat
# B05
# H8_HRIT_FLDK_B05_201806140630.dat
# B06
# H8_HRIT_FLDK_B06_201806140630.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140630.dat
# B10
# H8_HRIT_FLDK_B10_201806140630.dat
# B11
# H8_HRIT_FLDK_B11_201806140630.dat
# B12
# H8_HRIT_FLDK_B12_201806140630.dat
# B14
# H8_HRIT_FLDK_B14_201806140630.dat
# B16
# H8_HRIT_FLDK_B16_201806140630.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140630.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140630.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140630.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140630.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140630.dat
# ========= 201806140640 ===================
# B04
# H8_HRIT_FLDK_B04_201806140640.dat
# B05
# H8_HRIT_FLDK_B05_201806140640.dat
# B06
# H8_HRIT_FLDK_B06_201806140640.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140640.dat
# B10
# H8_HRIT_FLDK_B10_201806140640.dat
# B11
# H8_HRIT_FLDK_B11_201806140640.dat
# B12
# H8_HRIT_FLDK_B12_201806140640.dat
# B14
# H8_HRIT_FLDK_B14_201806140640.dat
# B16
# H8_HRIT_FLDK_B16_201806140640.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140640.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140640.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140640.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140640.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140640.dat
# ========= 201806140650 ===================
# B04
# H8_HRIT_FLDK_B04_201806140650.dat
# B05
# H8_HRIT_FLDK_B05_201806140650.dat
# B06
# H8_HRIT_FLDK_B06_201806140650.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140650.dat
# B10
# H8_HRIT_FLDK_B10_201806140650.dat
# B11
# H8_HRIT_FLDK_B11_201806140650.dat
# B12
# H8_HRIT_FLDK_B12_201806140650.dat
# B14
# H8_HRIT_FLDK_B14_201806140650.dat
# B16
# H8_HRIT_FLDK_B16_201806140650.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140650.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140650.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140650.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140650.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140650.dat
# ========= 201806140700 ===================
# B04
# H8_HRIT_FLDK_B04_201806140700.dat
# B05
# H8_HRIT_FLDK_B05_201806140700.dat
# B06
# H8_HRIT_FLDK_B06_201806140700.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140700.dat
# B10
# H8_HRIT_FLDK_B10_201806140700.dat
# B11
# H8_HRIT_FLDK_B11_201806140700.dat
# B12
# H8_HRIT_FLDK_B12_201806140700.dat
# B14
# H8_HRIT_FLDK_B14_201806140700.dat
# B16
# H8_HRIT_FLDK_B16_201806140700.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140700.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140700.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140700.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140700.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140700.dat
# ========= 201806140710 ===================
# B04
# H8_HRIT_FLDK_B04_201806140710.dat
# B05
# H8_HRIT_FLDK_B05_201806140710.dat
# B06
# H8_HRIT_FLDK_B06_201806140710.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140710.dat
# B10
# H8_HRIT_FLDK_B10_201806140710.dat
# B11
# H8_HRIT_FLDK_B11_201806140710.dat
# B12
# H8_HRIT_FLDK_B12_201806140710.dat
# B14
# H8_HRIT_FLDK_B14_201806140710.dat
# B16
# H8_HRIT_FLDK_B16_201806140710.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140710.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140710.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140710.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140710.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140710.dat
# ========= 201806140720 ===================
# B04
# H8_HRIT_FLDK_B04_201806140720.dat
# B05
# H8_HRIT_FLDK_B05_201806140720.dat
# B06
# H8_HRIT_FLDK_B06_201806140720.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140720.dat
# B10
# H8_HRIT_FLDK_B10_201806140720.dat
# B11
# H8_HRIT_FLDK_B11_201806140720.dat
# B12
# H8_HRIT_FLDK_B12_201806140720.dat
# B14
# H8_HRIT_FLDK_B14_201806140720.dat
# B16
# H8_HRIT_FLDK_B16_201806140720.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140720.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140720.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140720.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140720.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140720.dat
# ========= 201806140730 ===================
# B04
# H8_HRIT_FLDK_B04_201806140730.dat
# B05
# H8_HRIT_FLDK_B05_201806140730.dat
# B06
# H8_HRIT_FLDK_B06_201806140730.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140730.dat
# B10
# H8_HRIT_FLDK_B10_201806140730.dat
# B11
# H8_HRIT_FLDK_B11_201806140730.dat
# B12
# H8_HRIT_FLDK_B12_201806140730.dat
# B14
# H8_HRIT_FLDK_B14_201806140730.dat
# B16
# H8_HRIT_FLDK_B16_201806140730.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140730.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140730.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140730.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140730.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140730.dat
# ========= 201806140740 ===================
# B04
# H8_HRIT_FLDK_B04_201806140740.dat
# B05
# H8_HRIT_FLDK_B05_201806140740.dat
# B06
# H8_HRIT_FLDK_B06_201806140740.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140740.dat
# B10
# H8_HRIT_FLDK_B10_201806140740.dat
# B11
# H8_HRIT_FLDK_B11_201806140740.dat
# B12
# H8_HRIT_FLDK_B12_201806140740.dat
# B14
# H8_HRIT_FLDK_B14_201806140740.dat
# B16
# H8_HRIT_FLDK_B16_201806140740.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140740.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140740.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140740.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140740.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140740.dat
# ========= 201806140750 ===================
# B04
# H8_HRIT_FLDK_B04_201806140750.dat
# B05
# H8_HRIT_FLDK_B05_201806140750.dat
# B06
# H8_HRIT_FLDK_B06_201806140750.dat
# B07
# Data missing.
# B09
# H8_HRIT_FLDK_B09_201806140750.dat
# B10
# H8_HRIT_FLDK_B10_201806140750.dat
# B11
# H8_HRIT_FLDK_B11_201806140750.dat
# B12
# H8_HRIT_FLDK_B12_201806140750.dat
# B14
# H8_HRIT_FLDK_B14_201806140750.dat
# B16
# H8_HRIT_FLDK_B16_201806140750.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140750.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140750.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140750.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140750.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140750.dat
# ========= 201806140800 ===================
# B04
# H8_HRIT_FLDK_B04_201806140800.dat
# B05
# H8_HRIT_FLDK_B05_201806140800.dat
# B06
# H8_HRIT_FLDK_B06_201806140800.dat
# B07
# H8_HRIT_FLDK_B07_201806140800.dat
# B09
# H8_HRIT_FLDK_B09_201806140800.dat
# B10
# H8_HRIT_FLDK_B10_201806140800.dat
# B11
# H8_HRIT_FLDK_B11_201806140800.dat
# B12
# H8_HRIT_FLDK_B12_201806140800.dat
# B14
# H8_HRIT_FLDK_B14_201806140800.dat
# B16
# H8_HRIT_FLDK_B16_201806140800.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140800.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140800.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140800.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140800.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140800.dat
# ========= 201806140810 ===================
# B04
# H8_HRIT_FLDK_B04_201806140810.dat
# B05
# H8_HRIT_FLDK_B05_201806140810.dat
# B06
# H8_HRIT_FLDK_B06_201806140810.dat
# B07
# H8_HRIT_FLDK_B07_201806140810.dat
# B09
# H8_HRIT_FLDK_B09_201806140810.dat
# B10
# H8_HRIT_FLDK_B10_201806140810.dat
# B11
# H8_HRIT_FLDK_B11_201806140810.dat
# B12
# H8_HRIT_FLDK_B12_201806140810.dat
# B14
# H8_HRIT_FLDK_B14_201806140810.dat
# B16
# H8_HRIT_FLDK_B16_201806140810.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140810.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140810.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140810.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140810.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140810.dat
# ========= 201806140820 ===================
# B04
# H8_HRIT_FLDK_B04_201806140820.dat
# B05
# H8_HRIT_FLDK_B05_201806140820.dat
# B06
# H8_HRIT_FLDK_B06_201806140820.dat
# B07
# H8_HRIT_FLDK_B07_201806140820.dat
# B09
# H8_HRIT_FLDK_B09_201806140820.dat
# B10
# H8_HRIT_FLDK_B10_201806140820.dat
# B11
# H8_HRIT_FLDK_B11_201806140820.dat
# B12
# H8_HRIT_FLDK_B12_201806140820.dat
# B14
# H8_HRIT_FLDK_B14_201806140820.dat
# B16
# H8_HRIT_FLDK_B16_201806140820.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140820.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140820.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140820.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140820.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140820.dat
# ========= 201806140830 ===================
# B04
# H8_HRIT_FLDK_B04_201806140830.dat
# B05
# H8_HRIT_FLDK_B05_201806140830.dat
# B06
# H8_HRIT_FLDK_B06_201806140830.dat
# B07
# H8_HRIT_FLDK_B07_201806140830.dat
# B09
# H8_HRIT_FLDK_B09_201806140830.dat
# B10
# H8_HRIT_FLDK_B10_201806140830.dat
# B11
# H8_HRIT_FLDK_B11_201806140830.dat
# B12
# H8_HRIT_FLDK_B12_201806140830.dat
# B14
# H8_HRIT_FLDK_B14_201806140830.dat
# B16
# H8_HRIT_FLDK_B16_201806140830.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140830.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140830.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140830.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140830.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140830.dat
# ========= 201806140840 ===================
# B04
# H8_HRIT_FLDK_B04_201806140840.dat
# B05
# H8_HRIT_FLDK_B05_201806140840.dat
# B06
# H8_HRIT_FLDK_B06_201806140840.dat
# B07
# H8_HRIT_FLDK_B07_201806140840.dat
# B09
# H8_HRIT_FLDK_B09_201806140840.dat
# B10
# H8_HRIT_FLDK_B10_201806140840.dat
# B11
# H8_HRIT_FLDK_B11_201806140840.dat
# B12
# H8_HRIT_FLDK_B12_201806140840.dat
# B14
# H8_HRIT_FLDK_B14_201806140840.dat
# B16
# H8_HRIT_FLDK_B16_201806140840.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140840.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140840.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140840.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140840.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140840.dat
# ========= 201806140850 ===================
# B04
# H8_HRIT_FLDK_B04_201806140850.dat
# B05
# H8_HRIT_FLDK_B05_201806140850.dat
# B06
# H8_HRIT_FLDK_B06_201806140850.dat
# B07
# H8_HRIT_FLDK_B07_201806140850.dat
# B09
# H8_HRIT_FLDK_B09_201806140850.dat
# B10
# H8_HRIT_FLDK_B10_201806140850.dat
# B11
# H8_HRIT_FLDK_B11_201806140850.dat
# B12
# H8_HRIT_FLDK_B12_201806140850.dat
# B14
# H8_HRIT_FLDK_B14_201806140850.dat
# B16
# H8_HRIT_FLDK_B16_201806140850.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140850.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140850.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140850.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140850.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140850.dat
# ========= 201806140900 ===================
# B04
# H8_HRIT_FLDK_B04_201806140900.dat
# B05
# H8_HRIT_FLDK_B05_201806140900.dat
# B06
# H8_HRIT_FLDK_B06_201806140900.dat
# B07
# H8_HRIT_FLDK_B07_201806140900.dat
# B09
# H8_HRIT_FLDK_B09_201806140900.dat
# B10
# H8_HRIT_FLDK_B10_201806140900.dat
# B11
# H8_HRIT_FLDK_B11_201806140900.dat
# B12
# H8_HRIT_FLDK_B12_201806140900.dat
# B14
# H8_HRIT_FLDK_B14_201806140900.dat
# B16
# H8_HRIT_FLDK_B16_201806140900.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140900.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140900.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140900.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140900.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140900.dat
# ========= 201806140910 ===================
# B04
# H8_HRIT_FLDK_B04_201806140910.dat
# B05
# H8_HRIT_FLDK_B05_201806140910.dat
# B06
# H8_HRIT_FLDK_B06_201806140910.dat
# B07
# H8_HRIT_FLDK_B07_201806140910.dat
# B09
# H8_HRIT_FLDK_B09_201806140910.dat
# B10
# H8_HRIT_FLDK_B10_201806140910.dat
# B11
# H8_HRIT_FLDK_B11_201806140910.dat
# B12
# H8_HRIT_FLDK_B12_201806140910.dat
# B14
# H8_HRIT_FLDK_B14_201806140910.dat
# B16
# H8_HRIT_FLDK_B16_201806140910.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140910.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140910.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140910.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140910.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140910.dat
# ========= 201806140920 ===================
# B04
# H8_HRIT_FLDK_B04_201806140920.dat
# B05
# H8_HRIT_FLDK_B05_201806140920.dat
# B06
# H8_HRIT_FLDK_B06_201806140920.dat
# B07
# H8_HRIT_FLDK_B07_201806140920.dat
# B09
# H8_HRIT_FLDK_B09_201806140920.dat
# B10
# H8_HRIT_FLDK_B10_201806140920.dat
# B11
# H8_HRIT_FLDK_B11_201806140920.dat
# B12
# H8_HRIT_FLDK_B12_201806140920.dat
# B14
# H8_HRIT_FLDK_B14_201806140920.dat
# B16
# H8_HRIT_FLDK_B16_201806140920.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140920.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140920.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140920.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140920.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140920.dat
# ========= 201806140930 ===================
# B04
# H8_HRIT_FLDK_B04_201806140930.dat
# B05
# H8_HRIT_FLDK_B05_201806140930.dat
# B06
# H8_HRIT_FLDK_B06_201806140930.dat
# B07
# H8_HRIT_FLDK_B07_201806140930.dat
# B09
# H8_HRIT_FLDK_B09_201806140930.dat
# B10
# H8_HRIT_FLDK_B10_201806140930.dat
# B11
# H8_HRIT_FLDK_B11_201806140930.dat
# B12
# H8_HRIT_FLDK_B12_201806140930.dat
# B14
# H8_HRIT_FLDK_B14_201806140930.dat
# B16
# H8_HRIT_FLDK_B16_201806140930.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140930.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140930.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140930.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140930.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140930.dat
# ========= 201806140940 ===================
# B04
# H8_HRIT_FLDK_B04_201806140940.dat
# B05
# H8_HRIT_FLDK_B05_201806140940.dat
# B06
# H8_HRIT_FLDK_B06_201806140940.dat
# B07
# H8_HRIT_FLDK_B07_201806140940.dat
# B09
# H8_HRIT_FLDK_B09_201806140940.dat
# B10
# H8_HRIT_FLDK_B10_201806140940.dat
# B11
# H8_HRIT_FLDK_B11_201806140940.dat
# B12
# H8_HRIT_FLDK_B12_201806140940.dat
# B14
# H8_HRIT_FLDK_B14_201806140940.dat
# B16
# H8_HRIT_FLDK_B16_201806140940.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140940.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140940.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140940.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140940.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140940.dat
# ========= 201806140950 ===================
# B04
# H8_HRIT_FLDK_B04_201806140950.dat
# B05
# H8_HRIT_FLDK_B05_201806140950.dat
# B06
# H8_HRIT_FLDK_B06_201806140950.dat
# B07
# H8_HRIT_FLDK_B07_201806140950.dat
# B09
# H8_HRIT_FLDK_B09_201806140950.dat
# B10
# H8_HRIT_FLDK_B10_201806140950.dat
# B11
# H8_HRIT_FLDK_B11_201806140950.dat
# B12
# H8_HRIT_FLDK_B12_201806140950.dat
# B14
# H8_HRIT_FLDK_B14_201806140950.dat
# B16
# H8_HRIT_FLDK_B16_201806140950.dat
# IR1
# H8_HRIT_FLDK_IR1_201806140950.dat
# IR2
# H8_HRIT_FLDK_IR2_201806140950.dat
# IR3
# H8_HRIT_FLDK_IR3_201806140950.dat
# IR4
# H8_HRIT_FLDK_IR4_201806140950.dat
# VIS
# H8_HRIT_FLDK_VIS_201806140950.dat
# ========= 201806141000 ===================
# B04
# H8_HRIT_FLDK_B04_201806141000.dat
# B05
# H8_HRIT_FLDK_B05_201806141000.dat
# B06
# H8_HRIT_FLDK_B06_201806141000.dat
# B07
# H8_HRIT_FLDK_B07_201806141000.dat
# B09
# H8_HRIT_FLDK_B09_201806141000.dat
# B10
# H8_HRIT_FLDK_B10_201806141000.dat
# B11
# H8_HRIT_FLDK_B11_201806141000.dat
# B12
# H8_HRIT_FLDK_B12_201806141000.dat
# B14
# H8_HRIT_FLDK_B14_201806141000.dat
# B16
# H8_HRIT_FLDK_B16_201806141000.dat
# IR1
# H8_HRIT_FLDK_IR1_201806141000.dat
# IR2
# H8_HRIT_FLDK_IR2_201806141000.dat
# IR3
# H8_HRIT_FLDK_IR3_201806141000.dat
# IR4
# H8_HRIT_FLDK_IR4_201806141000.dat
# VIS
# H8_HRIT_FLDK_VIS_201806141000.dat
